# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open("time_vs_loc.p", "rb") as pf:
    result_dictionary = pickle.load(pf)

# %%
for number_loc in result_dictionary.keys():
    relavant= result_dictionary[number_loc]
    rounds = []
    for time in result_dictionary[number_loc].keys():
        r = relavant[time][0]
        rounds.append(r)
    plt.plot(relavant.keys(), rounds, label=str(number_loc))
plt.legend()

# %%
for number_loc in result_dictionary.keys():
    relavant= result_dictionary[number_loc]
    pathlen = []
    for time in result_dictionary[number_loc].keys():
        r = relavant[time][1]
        pathlen.append(r)
    plt.plot(relavant.keys(), pathlen, label=str(number_loc))
plt.ylim(0, 90)
plt.legend()

# %%
for number_loc in result_dictionary.keys():
    relavant= result_dictionary[number_loc]
    rewards = []
    for time in result_dictionary[number_loc].keys():
        r = relavant[time][2]
        rewards.append(r)
    plt.plot(relavant.keys(), rewards, label=str(number_loc))
plt.legend()
plt.ylim(0, 50)
# Out:
# (0.0, 50.0)

# %%
for number_loc in result_dictionary.keys():
    relavant= result_dictionary[number_loc]
    best_time = []
    for time in result_dictionary[number_loc].keys():
        r = relavant[time][3]
        best_time.append(r)
    plt.plot(relavant.keys(), best_time, label=str(number_loc))
plt.legend()
plt.ylim(0, 6500)
# Out:
# (0.0, 6500.0)

# %%
for number_loc in result_dictionary.keys():
    relavant= result_dictionary[number_loc]
    num_rew = []
    for time in result_dictionary[number_loc].keys():
        r = relavant[time][4]
        num_rew.append(r)
    plt.plot(relavant.keys(), num_rew, label=str(number_loc))
plt.legend()
